# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.random.rand(50)

# %%
y
# Out:
# array([ 0.6139763 ,  0.24427002,  0.50455826,  0.3531501 ,  0.16250084,
#         0.3958293 ,  0.78818432,  0.23368842,  0.70803156,  0.98284959,
#         0.94419951,  0.29678701,  0.19306138,  0.34317284,  0.00886636,
#         0.83712377,  0.93044259,  0.95732328,  0.2331941 ,  0.43923829,
#         0.82647531,  0.63098363,  0.17077704,  0.03052276,  0.60472958,
#         0.8686465 ,  0.97125725,  0.07375824,  0.42896917,  0.97624123,
#         0.55577219,  0.29352601,  0.42321063,  0.0704648 ,  0.0162195 ,
#         0.85730721,  0.54923741,  0.87221234,  0.40086083,  0.88715327,
#         0.18010981,  0.07620816,  0.33846792,  0.80550695,  0.56808329,
#         0.2565815 ,  0.74015902,  0.01859836,  0.07882823,  0.87041251])

# %%
plt.plot(y)

# %%
#0~10之間取100個點
x = np.linspace(0, 10, 100)

# %%
x
# Out:
# array([  0.        ,   0.1010101 ,   0.2020202 ,   0.3030303 ,
#          0.4040404 ,   0.50505051,   0.60606061,   0.70707071,
#          0.80808081,   0.90909091,   1.01010101,   1.11111111,
#          1.21212121,   1.31313131,   1.41414141,   1.51515152,
#          1.61616162,   1.71717172,   1.81818182,   1.91919192,
#          2.02020202,   2.12121212,   2.22222222,   2.32323232,
#          2.42424242,   2.52525253,   2.62626263,   2.72727273,
#          2.82828283,   2.92929293,   3.03030303,   3.13131313,
#          3.23232323,   3.33333333,   3.43434343,   3.53535354,
#          3.63636364,   3.73737374,   3.83838384,   3.93939394,
#          4.04040404,   4.14141414,   4.24242424,   4.34343434,
#          4.44444444,   4.54545455,   4.64646465,   4.74747475,
#          4.84848485,   4.94949495,   5.05050505,   5.15151515,
#          5.25252525,   5.35353535,   5.45454545,   5.55555556,
#          5.65656566,   5.75757576,   5.85858586,   5.95959596,
# ...

# %%
plt.plot(x, np.sin(x)+x)

# %%
plt.plot(x, np.sin(x)+x)
plt.plot(x, np.cos(x))
