# %% [markdown]
# # 第一題：
# 題目：給定一個矩陣m，裡面的值都大於0。
# 請將矩陣m裡大於等於1的數字都變成1，小於1的變成0。
#
# m = np.array([[0,1,10],[2,6,7]])
#
# 提示：使用巢狀迴圈(nested loop)加判斷式

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

matrix = np.array([[0,1,10],[2,6,7]])

(m,n) = np.shape(matrix)

for i in range(m):
    for j in range(n):
        if(matrix[i][j]>=1):
            matrix[i][j] = 1
        elif(matrix[i][j]<1):
            matrix[i][j] = 0
            
print(matrix)
# Out:
# [[0 1 1]
#  [1 1 1]]

# %% [markdown]
# # 第二題：
# 有A,B,C三個班級，每班皆有10個學生，期中考結束後，老師希望計算各班級每位學生的加權平均成績。
#
# 請隨機產生3個班級的成績單,每班10人,共五科,權重為weights=[0.25,0.25,0.25,0.15,0.10]。
# 請算出班級加權平均成績，並以一個array輸出。

# %%
grades = np.random.randint(0,100,(3,10,5))
weights=[0.25,0.25,0.25,0.15,0.10]
print(grades)

w_grades = grades * weights
avg_grades =np.sum(np.sum(w_grades,axis=2),axis=1)/10
print(avg_grades)
# Out:
# [[[85 25 45 60 40]
#   [66 44 58 24  0]
#   [34  7 65 90 44]
#   [64 88 65 26 63]
#   [ 2 88  2 29 43]
#   [58 36 51 38 80]
#   [52 48  3 99 68]
#   [74 13 57 78 34]
#   [79 17 75 51 68]
#   [25 58 81 97 58]]
#
#  [[ 0 18 46 70 58]
#   [10 55 14  2 72]
#   [26 78 37 95  7]
#   [36 64  8 31  3]
#   [84 51 69 47 98]
#   [41 18 17 45 77]
#   [99  9 85 21 48]
#   [39 73 98 47 53]
#   [15 98 24 37 71]
#   [27 87 30 47 29]]
#
#  [[57 18 35 82 24]
#   [48 68 91 81 21]
#   [ 5 20 21 15 40]
#   [91 83 94 67 71]
#   [70 32 24 37 25]
#   [17 21 86 37 90]
#   [95  0 45 36 84]
#   [33 90 94 80 61]
#   [45 54 31 76 46]
#   [45 29 48 82  1]]]
# [[[ 21.25   6.25  11.25   9.     4.  ]
#   [ 16.5   11.    14.5    3.6    0.  ]
#   [  8.5    1.75  16.25  13.5    4.4 ]
#   [ 16.    22.    16.25   3.9    6.3 ]
#   [  0.5   22.     0.5    4.35   4.3 ]
#   [ 14.5    9.    12.75   5.7    8.  ]
#   [ 13.    12.     0.75  14.85   6.8 ]
#   [ 18.5    3.25  14.25  11.7    3.4 ]
#   [ 19.75   4.25  18.75   7.65   6.8 ]
#   [  6.25  14.5   20.25  14.55   5.8 ]]
#
#  [[  0.     4.5   11.5   10.5    5.8 ]
#   [  2.5   13.75   3.5    0.3    7.2 ]
#   [  6.5   19.5    9.25  14.25   0.7 ]
#   [  9.    16.     2.     4.65   0.3 ]
#   [ 21.    12.75  17.25   7.05   9.8 ]
#   [ 10.25   4.5    4.25   6.75   7.7 ]
#   [ 24.75   2.25  21.25   3.15   4.8 ]
#   [  9.75  18.25  24.5    7.05   5.3 ]
#   [  3.75  24.5    6.     5.55   7.1 ]
#   [  6.75  21.75   7.5    7.05   2.9 ]]
#
#  [[ 14.25   4.5    8.75  12.3    2.4 ]
#   [ 12.    17.    22.75  12.15   2.1 ]
#   [  1.25   5.     5.25   2.25   4.  ]
#   [ 22.75  20.75  23.5   10.05   7.1 ]
#   [ 17.5    8.     6.     5.55   2.5 ]
#   [  4.25   5.25  21.5    5.55   9.  ]
#   [ 23.75   0.    11.25   5.4    8.4 ]
#   [  8.25  22.5   23.5   12.     6.1 ]
#   [ 11.25  13.5    7.75  11.4    4.6 ]
#   [ 11.25   7.25  12.    12.3    0.1 ]]]
# [ 50.485  45.69   50.775]

# %% [markdown]
# # 挑戰題一：
# 請定義一個全班高微成績的函式，輸入是一個(3, 30, 3)的array，
# 表示3個班級中30位學生的成績(小考，期中考，期末考)  。
#
# 目標輸出則是一個(3, 30, 1)的array，表示所有學生的期末成績，
# 期末成績計算方式如下：
#
# 1. 小考20%，期中考35%，期末考45%
# 2. 期中考40%，期末考60%。
# 擇優作為期末成績
#
# Hint
# * 可以用雙重for迴圈 分別跑過班級跟人
# * 可以先設一個array裝算出來的成績
# * 記得要用return
# * 請做個測試，檢驗你的結果，方便同學評分。

# %%
def grade_cal(list):
    w1 = [0.2, 0.35, 0.45]
    w2 = [0, 0.4, 0.6]

    
    g1 = list * w1
    g1 = np.sum(g1,axis=2)
    g2 = list * w2
    g2 = np.sum(g2,axis=2)
    m,n = np.shape(g1)
    result = np.zeros((m,n))
    
    for i in range(m):
        for j in range(n):
            result[i][j] = max(g1[i][j],g2[i][j])
    return result

grades = np.random.randint(0,100,(3,30,3))
print(grades)
grade_cal(grades)
# Out:
# [[[67 54 54]
#   [19 23 53]
#   [14 52 93]
#   [ 1 48  5]
#   [87 97  4]
#   [93 99 47]
#   [ 2 35  0]
#   [59  5  4]
#   [98 62 63]
#   [97 79 89]
#   [82 82 49]
#   [27  0 45]
#   [47  5 73]
#   [18 59 99]
#   [67 73 23]
#   [82 74 78]
#   [ 5 59  5]
#   [35 38 62]
#   [37 96 60]
#   [15 32 33]
#   [52 60 51]
#   [38 16 59]
#   [72 32 76]
#   [99  8 31]
#   [56 99 95]
#   [89  9 63]
#   [24  4  1]
#   [ 0 35 32]
#   [39 26 79]
#   [77 99 93]]
#
#  [[29 19 92]
#   [19 39 94]
#   [56  9 93]
#   [54 34 37]
#   [68 32 32]
#   [89 85 82]
#   [52  7 53]
#   [ 3 33 98]
#   [25 50 33]
#   [53 49 68]
#   [ 6 45 84]
#   [41 94 47]
#   [11 67  5]
#   [83  8 45]
#   [68 65 71]
#   [44 13 58]
#   [ 7 49 71]
#   [40 46 40]
#   [52 20 49]
#   [53 46 88]
#   [31 74 42]
#   [28 42 70]
#   [97 92 15]
#   [66 22 71]
#   [68 15 69]
#   [45 17 37]
#   [69 76 88]
#   [46 77 56]
#   [43 80 72]
#   [67 16 65]]
#
#  [[53 21 38]
#   [93 23 64]
#   [46 83  9]
#   [50 26 43]
#   [59 57 86]
#   [42 70 75]
#   [88 62 69]
#   [51 79 62]
#   [74 66 13]
#   [73 94 51]
#   [36 54 39]
#   [77 27 38]
#   [21 50 93]
#   [89 93 95]
#   [91 54 66]
#   [60 66 46]
#   [ 4 35  9]
#   [56  9 16]
#   [ 4  8  8]
#   [67 22 72]
#   [41 60 34]
#   [39 97  4]
#   [53 39 90]
#   [92 48 55]
#   [16 65 58]
#   [41 15 60]
#   [19  6 49]
#   [17 59 77]
#   [91 22 28]
#   [49 27 94]]]
# array([[ 56.6 ,  41.  ,  76.6 ,  22.2 ,  53.15,  74.4 ,  14.  ,  15.35,
#          69.65,  87.1 ,  67.15,  27.  ,  45.8 ,  83.  ,  49.3 ,  77.4 ,
#          26.6 ,  52.4 ,  74.4 ,  32.6 ,  54.6 ,  41.8 ,  59.8 ,  36.55,
#          96.6 ,  49.3 ,   6.65,  33.2 ,  57.8 ,  95.4 ],
#        [ 62.8 ,  72.  ,  59.4 ,  39.35,  39.2 ,  84.45,  36.7 ,  72.  ,
#          39.8 ,  60.4 ,  68.4 ,  65.8 ,  29.8 ,  39.65,  68.6 ,  40.  ,
#          62.2 ,  42.4 ,  39.45,  71.2 ,  54.8 ,  58.8 ,  58.35,  52.85,
#          49.9 ,  31.6 ,  83.2 ,  64.4 ,  75.2 ,  48.25],
#        [ 35.05,  55.45,  42.3 ,  38.45,  74.4 ,  73.  ,  70.35,  68.8 ,
#          43.75,  70.45,  45.  ,  41.95,  75.8 ,  94.2 ,  66.8 ,  55.8 ,
#          19.4 ,  21.55,   8.  ,  53.5 ,  44.5 ,  43.55,  69.6 ,  59.95,
#          60.8 ,  42.  ,  31.8 ,  69.8 ,  38.5 ,  67.2 ]])
