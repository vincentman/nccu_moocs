# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2)
# Out:
# 1.0

# %%
plot([-2,10,3,13,5])

# %%
randn(10)
# Out:
# array([ 0.02608955, -0.78892522,  0.41774441,  0.30203389, -0.03048023,
#        -1.22460285,  1.01690016, -0.72843977, -0.12324616, -0.25638325])

# %%
plot(randn(100))

# %%
plot([-2,1,2.7,3.3,],[3,-5,6,0])
